# %%
import shutil
from os import path
import os
import glob
import gdalimport shutil
from os import path
import os
import glob
import gdal

# %%
image_path= "E:/cowc/tiles/Image jpgs/test/"  ##cowc ground_truth_sets location after download
os.chdir(image_path)
images=glob.glob("*.jpg")

for image in images:
    anno_path = "E:/cowc/masks/Original Masks Png/"
    d_1 = os.path.join(anno_path,image)
    d_2 = d_1.replace('.png_tile_', '_Annotated_Cars.png_tile_')
    d_3 = d_2.replace('.jpg', '.png')
    print(d_3)
#     source_path = os.pa(d_3)
#     print(source_path)
#    Check the file exist or not

    if path.exists(d_3):

        destination_path = "E:/cowc/masks/Original Masks Png/test/"

        # Move the file to the new location

        new_location = shutil.move(d_3, destination_path)

        # Print the new location of the file

        print("The %s is moved to the location, %s" %(d_3, new_location))

    else:

        # Print the message if the file not exists

        print("File does not exist.")
# Out:
# E:/cowc/masks/Original Masks Png/03559_Annotated_Cars.png_tile_111.png
# The E:/cowc/masks/Original Masks Png/03559_Annotated_Cars.png_tile_111.png is moved to the location, E:/cowc/masks/Original Masks Png/test/03559_Annotated_Cars.png_tile_111.png
# E:/cowc/masks/Original Masks Png/03559_Annotated_Cars.png_tile_112.png
# The E:/cowc/masks/Original Masks Png/03559_Annotated_Cars.png_tile_112.png is moved to the location, E:/cowc/masks/Original Masks Png/test/03559_Annotated_Cars.png_tile_112.png
# E:/cowc/masks/Original Masks Png/03559_Annotated_Cars.png_tile_113.png
# The E:/cowc/masks/Original Masks Png/03559_Annotated_Cars.png_tile_113.png is moved to the location, E:/cowc/masks/Original Masks Png/test/03559_Annotated_Cars.png_tile_113.png
# E:/cowc/masks/Original Masks Png/03559_Annotated_Cars.png_tile_114.png
# ...
