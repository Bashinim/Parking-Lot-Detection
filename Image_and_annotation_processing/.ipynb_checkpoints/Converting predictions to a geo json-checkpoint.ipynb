# %%
import json
  
# Opening JSON file
f = open('F:/Berlin-DOP_2020/Processed images/Split_images_2/Test/Maskeddop10rgbi_391000.0_5824950.0_tile_1.json')
data = json.load(f)
f.close()

# %%
file_name_1 = f.name.replace("F:/Berlin-DOP_2020/Processed images/Split_images_2/Test/","")
file_name_2 = file_name_1.replace(".json","")
file_name_3 = f.name.replace(".json",".geojson")

# %%
iteration = 0
x_cor = float(str(file_name_2.split('_')[1]))
y_cor = float(str(file_name_2.split('_')[2]))
json_file = {}
json_file["type"] = "FeatureCollection"
json_file["name"] = file_name_2
json_file["crs"] = { "type": "name", "properties": { "name": "urn:ogc:def:crs:EPSG::25833" }}
json_file["features"] = []
for i in data['shapes']:
    iteration = iteration+1
    label = i['label']
    cords = i['points']
    cord_final = []
    for j in cords:
        cord = j
        x = cord[0]*0.1
        y = cord[1]*0.1
        x_rel = x_cor+x
        y_rel = y_cor+y
        cord_f = [x_rel,y_rel]
        cord_final.append(cord_f)
    other = {"type": "Feature", "properties": { "id": iteration, "label": label}, 
                         "geometry":{ "type": "MultiPolygon", "coordinates": [[cord_final]]}}
    json_file["features"].append(other)

# %%
with open(file_name_3, 'w') as file:
    json.dump(json_file, file,indent=4,  separators=(',', ':',))

# %%
json_file
# Out:
# {'type': 'FeatureCollection',
#  'name': 'Maskeddop10rgbi_391000.0_5824950.0_tile_1',
#  'crs': {'type': 'name',
#   'properties': {'name': 'urn:ogc:def:crs:EPSG::25833'}},
#  'features': [{'type': 'Feature',
#    'properties': {'id': 1, 'label': 'PK-space-occupied'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[391013.95, 5824990.4],
#        [391013.65, 5824989.5],
#        [391013.3, 5824989.15],
#        [391013.1, 5824989.05],
#        [391012.6, 5824989.15],
#        [391011.55, 5824990.2],
#        [391007.85, 5824994.8],
#        [391007.35, 5824995.8],
#        [391007.45, 5824996.4],
#        [391007.7, 5824996.65],
#        [391008.9, 5824996.65],
#        [391009.1, 5824996.55],
#        [391011.35, 5824993.2],
#        [391013.55, 5824991.1],
#        [391013.95, 5824990.4]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': 2, 'label': 'PK-space-occupied'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[391007.85, 5824983.5],
#        [391007.85, 5824983.0],
#        [391007.4, 5824982.45],
#        [391006.8, 5824982.15],
#        [391006.1, 5824982.25],
#        [391005.55, 5824982.7],
#        [391005.15, 5824983.5],
#        [391004.65, 5824984.1],
#        [391004.45, 5824984.5],
#        [391004.45, 5824984.9],
#        [391004.9, 5824985.55],
#        [391005.4, 5824985.85],
#        [391005.7, 5824985.85],
#        [391006.65, 5824985.0],
#        [391007.85, 5824983.5]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': 3, 'label': 'PK-space-occupied'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[391018.25, 5824970.9],
#        [391018.05, 5824970.3],
#        [391017.4, 5824969.85],
#        [391017.0, 5824969.75],
#        [391016.2, 5824969.95],
#        [391015.85, 5824970.4],
#        [391015.45, 5824971.5],
#        [391014.95, 5824972.1],
#        [391014.85, 5824972.9],
#        [391015.6, 5824973.55],
#        [391016.3, 5824973.45],
#        [391016.55, 5824973.2],
#        [391016.85, 5824972.5],
#        [391017.2, 5824972.15],
#        [391017.4, 5824972.15],
#        [391018.05, 5824971.5],
#        [391018.25, 5824970.9]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': 4, 'label': 'PK-space-occupied'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[391022.55, 5824980.5],
#        [391022.55, 5824979.5],
#        [391022.35, 5824979.1],
#        [391021.8, 5824978.65],
#        [391021.3, 5824978.75],
#        [391019.75, 5824980.4],
#        [391018.95, 5824981.6],
#        [391018.85, 5824981.8],
#        [391018.85, 5824982.8],
#        [391019.0, 5824982.95],
#        [391020.4, 5824982.95],
#        [391020.6, 5824982.85],
#        [391022.15, 5824981.4],
#        [391022.55, 5824980.5]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': 5, 'label': 'PK-space-occupied'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[391003.65, 5824988.2],
#        [391003.55, 5824988.1],
#        [391003.55, 5824987.6],
#        [391003.2, 5824987.15],
#        [391002.3, 5824987.15],
#        [391002.1, 5824987.25],
#        [391000.75, 5824988.6],
#        [391000.05, 5824989.6],
#        [391000.05, 5824991.1],
#        [391000.5, 5824991.25],
#        [391001.2, 5824990.95],
#        [391001.9, 5824990.05],
#        [391003.35, 5824989.0],
#        [391003.65, 5824988.2]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': 6, 'label': 'PK-space-occupied'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[391022.15, 5824966.3],
#        [391022.15, 5824965.7],
#        [391021.85, 5824964.9],
#        [391021.6, 5824964.65],
#        [391020.7, 5824964.45],
#        [391020.5, 5824964.45],
#        [391019.9, 5824965.15],
#        [391019.6, 5824965.25],
#        [391019.25, 5824965.9],
#        [391019.25, 5824966.7],
#        [391019.45, 5824967.1],
#        [391020.0, 5824967.65],
#        [391020.3, 5824967.65],
#        [391020.8, 5824967.35],
#        [391021.5, 5824967.15],
#        [391021.95, 5824966.7],
#        [391022.15, 5824966.3]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': 7, 'label': 'PK-space-occupied'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[391017.45, 5824950.0],
#        [391017.1, 5824950.05],
#        [391016.95, 5824950.2],
#        [391016.95, 5824951.2],
#        [391017.85, 5824952.6],
#        [391018.15, 5824953.9],
#        [391018.3, 5824954.05],
#        [391019.5, 5824954.05],
#        [391019.8, 5824953.95],
#        [391020.15, 5824953.6],
#        [391020.15, 5824952.1],
#        [391019.35, 5824950.7],
#        [391018.65, 5824950.0]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': 8, 'label': 'PK-space-occupied'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[391018.05, 5824971.4],
#        [391018.05, 5824970.4],
#        [391017.8, 5824970.05],
#        [391017.2, 5824970.05],
#        [391017.1, 5824969.95],
#        [391016.3, 5824970.05],
#        [391015.95, 5824970.4],
#        [391015.25, 5824971.6],
#        [391014.7, 5824972.15],
#        [391013.8, 5824972.55],
#        [391013.05, 5824973.4],
#        [391012.35, 5824974.5],
#        [391010.95, 5824975.9],
#        [391010.45, 5824976.8],
#        [391010.55, 5824977.6],
#        [391011.1, 5824978.15],
#        [391011.5, 5824978.35],
#        [391012.3, 5824978.35],
#        [391012.7, 5824978.15],
#        [391013.45, 5824977.4],
#        [391013.85, 5824976.7],
#        [391015.05, 5824975.5],
#        [391015.75, 5824974.2],
#        [391016.75, 5824973.2],
#        [391017.15, 5824972.4],
#        [391018.05, 5824971.4]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': 9, 'label': 'PK-space-empty'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[391021.05, 5824967.7],
#        [391021.0, 5824967.35],
#        [391020.3, 5824967.25],
#        [391019.9, 5824966.85],
#        [391019.6, 5824966.85],
#        [391019.15, 5824966.4],
#        [391019.0, 5824966.05],
#        [391018.8, 5824965.95],
#        [391018.35, 5824966.0],
#        [391018.25, 5824966.2],
#        [391018.25, 5824967.9],
#        [391017.45, 5824969.2],
#        [391017.55, 5824969.7],
#        [391017.95, 5824970.1],
#        [391018.3, 5824970.85],
#        [391019.2, 5824970.85],
#        [391019.45, 5824970.6],
#        [391019.95, 5824969.4],
#        [391020.85, 5824968.2],
#        [391021.05, 5824967.7]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': 10, 'label': 'PK-space-empty'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[391005.85, 5824986.7],
#        [391005.85, 5824986.1],
#        [391004.8, 5824985.45],
#        [391004.2, 5824984.65],
#        [391003.3, 5824984.65],
#        [391002.85, 5824985.7],
#        [391002.55, 5824985.9],
#        [391002.55, 5824986.4],
#        [391002.75, 5824986.8],
#        [391003.1, 5824986.95],
#        [391003.15, 5824987.2],
#        [391003.35, 5824987.3],
#        [391003.8, 5824988.45],
#        [391003.9, 5824988.35],
#        [391004.0, 5824988.45],
#        [391004.4, 5824988.35],
#        [391005.85, 5824986.7]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': 11, 'label': 'PK-space-empty'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[391006.15, 5824986.6],
#        [391006.15, 5824986.3],
#        [391005.9, 5824985.95],
#        [391005.5, 5824985.85],
#        [391005.2, 5824985.55],
#        [391004.9, 5824985.55],
#        [391004.75, 5824985.2],
#        [391004.35, 5824985.0],
#        [391004.35, 5824984.5],
#        [391004.25, 5824984.4],
#        [391004.35, 5824983.9],
#        [391004.65, 5824983.6],
#        [391004.5, 5824983.45],
#        [391004.2, 5824983.25],
#        [391003.9, 5824983.35],
#        [391003.2, 5824983.15],
#        [391003.1, 5824983.25],
#        [391002.6, 5824983.15],
#        [391002.45, 5824983.3],
#        [391002.35, 5824984.0],
#        [391001.85, 5824985.0],
#        [391001.55, 5824985.2],
#        [391001.4, 5824985.55],
#        [391001.0, 5824985.65],
#        [391000.55, 5824986.1],
#        [391000.55, 5824987.6],
#        [391000.9, 5824987.95],
#        [391001.5, 5824987.65],
#        [391001.8, 5824987.65],
#        [391002.0, 5824987.25],
#        [391003.3, 5824987.25],
#        [391003.45, 5824987.6],
#        [391003.75, 5824987.8],
#        [391004.0, 5824988.35],
#        [391004.1, 5824988.25],
#        [391004.6, 5824988.25],
#        [391006.05, 5824986.9],
#        [391006.15, 5824986.6]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': 12, 'label': 'PK-space-occupied'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[391025.85, 5824976.1],
#        [391025.75, 5824975.0],
#        [391025.4, 5824974.65],
#        [391024.7, 5824974.75],
#        [391023.55, 5824975.9],
#        [391021.75, 5824978.2],
#        [391019.75, 5824980.4],
#        [391019.15, 5824981.5],
#        [391019.15, 5824982.5],
#        [391020.9, 5824982.55],
#        [391021.1, 5824982.45],
#        [391022.25, 5824981.2],
#        [391022.85, 5824979.6],
#        [391024.45, 5824978.3],
#        [391025.45, 5824977.0],
#        [391025.85, 5824976.1]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': 13, 'label': 'PK-space-occupied'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[391009.95, 5824966.4],
#        [391009.95, 5824966.0],
#        [391009.15, 5824965.2],
#        [391009.05, 5824964.9],
#        [391008.5, 5824964.85],
#        [391006.85, 5824966.9],
#        [391006.25, 5824968.2],
#        [391006.25, 5824969.1],
#        [391007.5, 5824969.05],
#        [391008.95, 5824967.7],
#        [391009.95, 5824966.4]]]]}}]}
